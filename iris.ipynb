# %% [markdown]
# <a href="https://colab.research.google.com/github/karthikm2305/Iris_visual/blob/main/iris.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
flower=pd.read_csv("/content/IRIS.csv")

# %%
flower.head(25)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
flower.shape
# Out:
# (150, 5)

# %%
flower.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
sns.pairplot(flower,hue="species")

# %%
flower["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %%
flower=pd.read_csv("/content/IRIS.csv")
flower.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
flower.head(150)
sns.lineplot(x="sepal_width",y="sepal_length",data=flower)
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %%
g = sns.FacetGrid(flower, hue="species", height=6)
g.map(plt.scatter, 'petal_length', 'sepal_width').add_legend()
plt.show()

# %%
flower=pd.read_csv("/content/IRIS.csv")
import pandas as pd
columns_to_extract = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
x = flower[columns_to_extract].values

# %%
flower[['species']].values
# Out:
# array([['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
# ...

# %%
counts = flower['species'].groupby(flower['sepal_length']).count()
x = counts.index
y = counts.values
plt.xlabel('Sepal Length')
plt.ylabel('Number of Occurrences')
plt.bar(x, y)
plt.show()

# %%
import seaborn as sns
sns.countplot(x="species",data=flower)
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
flower=len(flower)
print(flower)
# Out:
# 150

# %%
x=flower[['sepal_length','sepal_width','petal_length','petal_width']].values
y=flower[['species']].values
print(x)
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
print(y_test)
# Out:
# [['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-virginica']
#  ['Iris-virginica']
#  ['Iris-setosa']
#  ['Iris-virginica']
#  ['Iris-virginica']
#  ['Iris-setosa']
#  ['Iris-virginica']
#  ['Iris-versicolor']
#  ['Iris-virginica']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-virginica']
#  ['Iris-versicolor']
#  ['Iris-virginica']
#  ['Iris-setosa']
#  ['Iris-setosa']
#  ['Iris-versicolor']
#  ['Iris-virginica']
#  ['Iris-virginica']
#  ['Iris-versicolor']
#  ['Iris-virginica']
#  ['Iris-virginica']
#  ['Iris-versicolor']
#  ['Iris-versicolor']
#  ['Iris-virginica']]

# %%
print(x_test)
# Out:
# [[4.8 3.  1.4 0.3]
#  [5.1 3.7 1.5 0.4]
#  [6.4 3.1 5.5 1.8]
#  [6.7 2.5 5.8 1.8]
#  [4.6 3.1 1.5 0.2]
#  [6.7 3.  5.2 2.3]
#  [6.3 2.7 4.9 1.8]
#  [5.2 4.1 1.5 0.1]
#  [7.1 3.  5.9 2.1]
#  [4.9 2.4 3.3 1. ]
#  [6.7 3.3 5.7 2.1]
#  [5.  3.5 1.3 0.3]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.9 0.2]
#  [5.7 3.8 1.7 0.3]
#  [4.4 2.9 1.4 0.2]
#  [7.4 2.8 6.1 1.9]
#  [5.8 2.6 4.  1.2]
#  [6.1 2.6 5.6 1.4]
#  [5.  3.4 1.6 0.4]
#  [5.  3.3 1.4 0.2]
#  [5.5 2.4 3.7 1. ]
#  [6.8 3.  5.5 2.1]
#  [6.2 2.8 4.8 1.8]
#  [6.2 2.9 4.3 1.3]
#  [6.9 3.1 5.1 2.3]
#  [7.2 3.6 6.1 2.5]
#  [5.7 3.  4.2 1.2]
#  [5.5 2.4 3.8 1.1]
#  [6.9 3.2 5.7 2.3]]

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x,y)
model.score(x,y)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.9733333333333334

# %%
expected=y
predicted=model.predict(x)
print(predicted)
# Out:
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
# ...

# %%
from sklearn.metrics import confusion_matrix
conf_matrix = confusion_matrix(expected, predicted)
print("Confusion Matrix:",conf_matrix)
# Out:
# Confusion Matrix: [[50  0  0]
#  [ 0 47  3]
#  [ 0  1 49]]

# %%
sns.scatterplot(data=flower, x='sepal_length', y='sepal_width', hue='species')
plt.show()

# %%
sns.scatterplot(data=flower, x='petal_length', y='petal_width', hue='species')
plt.show()

# %% [markdown]
# THANK YOU
